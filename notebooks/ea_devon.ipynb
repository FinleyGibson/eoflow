# %%
from pathlib import Path
from eoflow.ea import EAWaterQualityAPI, get_ea_water_quality
from eoflow.utils import load_shapefile
import folium

# %%
try:
    file_path = Path(__file__).resolve()
except NameError:
    file_path = Path.cwd()

shapefile_path = file_path.parent.parent.parent / "data/Counties_and_Unitary_Authorities_December_2023_Boundaries"
assert shapefile_path.is_dir()

# %%
shapefile_path
# Out:
# PosixPath('/home/finley/Work/RDS/projects/enforce/data/Counties_and_Unitary_Authorities_December_2023_Boundaries')

# %%
gdf = load_shapefile(path=shapefile_path)
devon_gdf = gdf[gdf["CTYUA23NM"] == "Devon"]
devon_gdf
# Out:
#      CTYUA23CD CTYUA23NM CTYUA23NMW   BNG_E  BNG_N     LONG      LAT  \
# 134  E10000008     Devon       None  283143  93085 -3.65698  50.7256
#
#                                  GlobalID  \
# 134  7aa8a35e-fa29-49bf-ac91-e4b121754500
#
#                                               geometry
# 134  MULTIPOLYGON (((264838.577 43779.215, 264643.3...

# %%
devon_gdf = devon_gdf.to_crs(epsg=4326)

# # Compute a sensible center for the map
geom_name = devon_gdf.geometry.name
centroid = devon_gdf.geometry.unary_union.centroid
map_center = [centroid.y, centroid.x]

# tooltip_fields = [c for c in gdf.columns if c != geom_name][:5]
# tooltip = folium.GeoJsonTooltip(fields=tooltip_fields, aliases=tooltip_fields) if tooltip_fields else None

m = folium.Map(
    location=map_center, 
    zoom_start=9,
    width="100%",
    height="500px",
    scrollWheelZoom=False)

folium.GeoJson(
    devon_gdf.__geo_interface__,
    name="shapefile",
    style_function=lambda feat: {
        "fillColor": "#ff7800",
        "color": "black",
        "weight": 0.5,
        "fillOpacity": 0.4,
    },
).add_to(m)

folium.LayerControl().add_to(m)

# Display the map
m
# Out:
# /tmp/ipykernel_233795/1854933694.py:5: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = devon_gdf.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0b84e75d8f55c1a2faab18d81777352 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0b84e75d8f55c1a2faab18d81777352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0b84e75d8f55c1a2faab18d81777352 = L.map(
#                 &quot;map_f0b84e75d8f55c1a2faab18d81777352&quot;,
#                 {
#                     center: [50.76161439647405, -3.8105494417484254],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;scrollWheelZoom&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3696f9b984b38f51723bd25d6e049975 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3696f9b984b38f51723bd25d6e049975.addTo(map_f0b84e75d8f55c1a2faab18d81777352);
#
#
#         function geo_json_bd2a682fabba736d184e5bfa754d175b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff7800&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 0.5};
#             }
#         }
#
#         function geo_json_bd2a682fabba736d184e5bfa754d175b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_bd2a682fabba736d184e5bfa754d175b = L.geoJson(null, {
#                 onEachFeature: geo_json_bd2a682fabba736d184e5bfa754d175b_onEachFeature,
#
#                 style: geo_json_bd2a682fabba736d184e5bfa754d175b_styler,
#             ...{
# }
#         });
#
#         function geo_json_bd2a682fabba736d184e5bfa754d175b_add (data) {
#             geo_json_bd2a682fabba736d184e5bfa754d175b
#                 .addData(data);
#         }
#             geo_json_bd2a682fabba736d184e5bfa754d175b_add({&quot;bbox&quot;: [-4.680539331986832, 50.20289500600769, -2.887025534544741, 51.24639390581138], &quot;features&quot;: [{&quot;bbox&quot;: [-4.680539331986832, 50.20289500600769, -2.887025534544741, 51.24639390581138], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[
# 2  SOUTH WEST - DEVON AND CORNWALL     EAST DEVON AND CORNWALL
# 3  SOUTH WEST - DEVON AND CORNWALL  CENTRAL DEVON AND CORNWALL
# 4  SOUTH WEST - DEVON AND CORNWALL  CENTRAL DEVON AND CORNWALL
#
#   samplingPoint.samplingPointStatus samplingPoint.samplingPointType  \
# 0                              OPEN             FRESHWATER - RIVERS
# 1                              OPEN             FRESHWATER - RIVERS
# 2                              OPEN             FRESHWATER - RIVERS
# 3                              OPEN             FRESHWATER - RIVERS
# 4                              OPEN             FRESHWATER - RIVERS
#
#         phenomenonTime                                    samplingPurpose  \
# 0  2020-01-14 10:11:00       MONITORING  (UK GOVT POLICY - NOT GQA OR RE)
# 1  2020-01-22 11:36:00       MONITORING  (UK GOVT POLICY - NOT GQA OR RE)
# 2  2020-01-20 11:57:00  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 3  2020-01-09 11:21:00  ENVIRONMENTAL MONITORING STATUTORY (EU DIRECTI...
# 4  2020-01-10 15:32:00  UNPLANNED REACTIVE MONITORING (POLLUTION INCID...
#
#               sampleMaterialType  determinand.notation determinand.prefLabel  \
# 0  RIVER / RUNNING SURFACE WATER                  6396             Turbidity
# 1  RIVER / RUNNING SURFACE WATER                  6396             Turbidity
# 2  RIVER / RUNNING SURFACE WATER                  6396             Turbidity
# 3  RIVER / RUNNING SURFACE WATER                  6396             Turbidity
# 4  POND / LAKE / RESERVOIR WATER                  6396             Turbidity
#
#   result                           unit        Date  result_numeric
# 0     57  NEPHELOMETRIC TURBIDITY UNITS  2020-01-14            57.0
# 1    8.6  NEPHELOMETRIC TURBIDITY UNITS  2020-01-22             8.6
# 2    5.9  NEPHELOMETRIC TURBIDITY UNITS  2020-01-20             5.9
# 3     15  NEPHELOMETRIC TURBIDITY UNITS  2020-01-09            15.0
# 4    1.7  NEPHELOMETRIC TURBIDITY UNITS  2020-01-10             1.7

# %%
ea_df.columns
# Out:
# Index(['id', 'samplingPoint.notation', 'samplingPoint.prefLabel',
#        'samplingPoint.easting', 'samplingPoint.northing',
#        'samplingPoint.region', 'samplingPoint.area', 'samplingPoint.subArea',
#        'samplingPoint.samplingPointStatus', 'samplingPoint.samplingPointType',
#        'phenomenonTime', 'samplingPurpose', 'sampleMaterialType',
#        'determinand.notation', 'determinand.prefLabel', 'result', 'unit',
#        'Date', 'result_numeric'],
#       dtype='object')

# %%
import pandas as pd
from pyproj import Transformer

# assuming your dataframe is called df
transformer = Transformer.from_crs(
    "EPSG:27700",  # British National Grid
    "EPSG:4326",   # WGS84 (lat/lon)
    always_xy=True
)

ea_df["lon"], ea_df["lat"] = transformer.transform(
    ea_df["samplingPoint.easting"].values,
    ea_df["samplingPoint.northing"].values
)

# %%
for _, row in ea_df.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"""
        <b>{row['samplingPoint.prefLabel']}</b><br>
        Determinand: {row['determinand.prefLabel']}<br>
        Result: {row['result']} {row['unit']}<br>
        Date: {row['Date']}
        """
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0b84e75d8f55c1a2faab18d81777352 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0b84e75d8f55c1a2faab18d81777352&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0b84e75d8f55c1a2faab18d81777352 = L.map(
#                 &quot;map_f0b84e75d8f55c1a2faab18d81777352&quot;,
#                 {
#                     center: [50.76161439647405, -3.8105494417484254],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;scrollWheelZoom&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3696f9b984b38f51723bd25d6e049975 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_