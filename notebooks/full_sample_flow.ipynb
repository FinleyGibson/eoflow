# %% [markdown]
# # Full EA sample processing
#
# Demonstrates the process for `eoflow.samples`
#
# ---
#
# ### Contents
#
# 1. Imports & configuration
# 2. Load Devon data
# 3. Soil types for the whole Devon county polygon
# 4. Devon county soil map (interactive)
# 5. Soil coverage for each sample catchment
# 6. Devon overview map — soil layer + catchments
# 7. Cross-catchment heatmap
# 8. Summary
#
# ---
#
# **Dataset:** [DefraSoilStructureGroups20240617](https://www.arcgis.com/home/item.html?id=af498634e7c2409c8a0e3eecb720f8dc)
# **Publisher:** Environment Agency / Cranfield University
# **Licence:** LandIS Open Licence (open data)
# **Native CRS:** EPSG:27700 British National Grid

# %%
from eoflow.samples import CatchmenSample
# Out:
# Failed to start the Kernel.
#
# The kernel died. Error: ... View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
